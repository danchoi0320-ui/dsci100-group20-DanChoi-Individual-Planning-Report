# %% [markdown]
# # Individual Planning Report

# %% [markdown]
# ### Introduction: A question that we will be exploring

# %% [markdown]
# A broad question: “We are interested in demand forecasting, namely, what time windows are most likely to have large number of simultaneous players. This is because we need to ensure that the number of licenses on hand is sufficiently large to accommodate all parallel players with high probability.”
#
# **My formulated question: Which time windows during the day and which days of the week are most likely to have a large number of engaged players?**
#
# In Minecraft, playing the game has a much greater impact on server traffic than just connecting to the server; hence, if we want to enhance the experience of players by minimizing issues related to the server, such as lag and connectivity issues, we would have to understand data related to engaged players, a player that would play the game long enough to have a impact on server traffick.
#
# In this project, an engaged player is defined arbitrarily as players who play more than 1 hour per session.
